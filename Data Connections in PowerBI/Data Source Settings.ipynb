# %% [markdown]
# # Data Source Settings
#
# In this chapter, you'll learn how to create parameters that can be used for incremental refreshes. You will also implement an incremental refresh on your data connection. Finally, you'll understand how M Language can be utilized to tackle issues with your data import processes.

# %% [markdown]
# # Incremental refresh
#
# Incremental refreshes can be a very useful feature for organizations that have implemented Power BI for their data visualization needs. It can help improve the efficiency of visualization tasks, by only carrying out refreshes of the data that actually needs to be updated.
#
# Which of the following statements is Not true regarding the incremental refresh feature?
#
# ![Screenshot 2025-12-27 201515.png](<attachment:Screenshot 2025-12-27 201515.png>)

# %% [markdown]
# # Parameters: true or false?
# As you have seen, parameters can be a very useful feature of Power BI, with a number of different applications possible.
#
# Having been introduced to the essential processes for the creation and application of parameters, can you identify which of the following statements regarding parameters are true or not?
#
# ![Screenshot 2025-12-27 202446.png](<attachment:Screenshot 2025-12-27 202446.png>)

# %% [markdown]
# # Query parameters
#
# Your manager informs you that WWI will be publishing reports to Power BI Service, and that the data sources you are using will be updated more regularly with even more data.
#
# As a result, you will have to create an incremental refresh process for your database data connection. In order to do this, you will also have to create the necessary parameters.

# %% [markdown]
# # M Language examined
#
# Even a basic understanding of M Language can be really helpful when it comes to working with data connections in Power BI. It allows us to identify problems in our connections when they arise and fix them using M Language in Power Query Editor.
#
# Therefore, with regards to M Language, which of the following statements is True?
#
# ![Screenshot 2025-12-27 210603.png](<attachment:Screenshot 2025-12-27 210603.png>)

# %% [markdown]
# # Using M Language on connections
#
# Your colleagues at WWI have been using the report you have built, as well as the data sources that feed into Power BI. However, they have made changes and you will have to investigate what has occurred. You will have to use Power Query Editor and M Language to carry out maintenance on your report.
