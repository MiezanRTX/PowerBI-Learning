# %% [markdown]
# # Storage modes
#
# When working with Power BI in corporate environments, you will come across many different types of data sources and data management systems.
#
# Knowledge of the different storage modes that are available within Power BI, particularly the two most commonly used, will ensure you are able to connect using the most appropriate way with any data source you encounter.
#
# ![Screenshot 2025-12-26 220229.png](<attachment:Screenshot 2025-12-26 220229.png>)
