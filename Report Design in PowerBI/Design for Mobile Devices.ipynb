# %% [markdown]
# # Mobile layout capabilities
#
# Which of the following statements are true about the mobile layout in Power BI?
#
# ![Screenshot 2025-12-25 141433.png](<attachment:Screenshot 2025-12-25 141433.png>)

# %% [markdown]
# # Create a mobile layout
#
# Senior leadership at the Wake County Watchdog program have found it difficult to engage with the report from mobile devices. They would like you to create and manage a new mobile report. Instead of doing that, however, let's show them the capabilities in Power BI to create a mobile-friendly layout.
#
# ![Screenshot 2025-12-25 144926.png](<attachment:Screenshot 2025-12-25 144926.png>)
#
# ![Screenshot 2025-12-25 144917.png](<attachment:Screenshot 2025-12-25 144917.png>)
#
# ![Screenshot 2025-12-25 144849.png](<attachment:Screenshot 2025-12-25 144849.png>)

# %% [markdown]
# # Progressive disclosure on mobile
#
# Management is impressed with what we have done so far on the Department Breakdown page and would like something similar for the Over Budget page. In this exercise, we will create a mobile layout which shows off our reporting capabilities and still includes some of the concepts of progressive disclosure.
#
# ![Screenshot 2025-12-25 154444.png](<attachment:Screenshot 2025-12-25 154444.png>)
#
# ![Screenshot 2025-12-25 154514.png](<attachment:Screenshot 2025-12-25 154514.png>)
#
# ![Screenshot 2025-12-25 154543.png](<attachment:Screenshot 2025-12-25 154543.png>)
#
# ![Screenshot 2025-12-25 154553.png](<attachment:Screenshot 2025-12-25 154553.png>)
#
# ![Screenshot 2025-12-25 154601.png](<attachment:Screenshot 2025-12-25 154601.png>)

# %% [markdown]
# # Make it mobile-friendly
#
# The mobile layout is a hit. Naturally, with success comes change requests. Management would love to see the number of expenditures but only on the mobile layout--they do not want to see it on the desktop layout. Further, the other Power BI developer recently discovered the bookmark navigator button and would like to switch out the three buttons for a mobile-friendly navigator option.
#
# ![Screenshot 2025-12-25 162743.png](<attachment:Screenshot 2025-12-25 162743.png>)
#
# ![Screenshot 2025-12-25 162723.png](<attachment:Screenshot 2025-12-25 162723.png>)
