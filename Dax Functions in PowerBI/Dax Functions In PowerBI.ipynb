# %% [markdown]
# # Chapter 1: DAX for creating tables and columns
# ## Keypoints
# - Difference between Measured and Calculated columns
# - Types of context
#     - row
#     - query
#     - filter
#
# ## Dataset
# - World wide importers dataset
#     -   Wholesaler who imports and distributes novelty goods
# - Consists of table that detailing sales transactions

# %% [markdown]
# ---

# %% [markdown]
# ## Exercise 1.1
# Steps
# 1. Created date table using DAX
#     - use CALENDAR(MIN(), MAX())
#     - connect/join it with Fact table
# 2. Create new column
#     -   Replacing text using SUBSTITUTE() with "" (Blank)
# 3. Creating Scenario ???
#     - Using RELATED()
#     - Visualize using area chart

# %% [markdown]
# ---

# %% [markdown]
# ### Step 1 : Creating a date table
# Dimensional date tables are necessary to ensure that calculations, such as DAX time-intelligence functions, have all available dates. This ensures there are no gaps between dates, so you don't receive any errors while performing these calculations.
#
# In this exercise you will create a delivery date table because we already have a date table for invoices. More specifically, you will create a date table that ranges from the minimum delivery date to the maximum delivery date.
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ---

# %% [markdown]
# ### Step 2 : Calculated Column for Costs
# Fact tables are typically only provided with the bare essential data needed, so sometimes you need to create extra calculated columns to find the answer to a business question. In this exercise you'll create a cost column in your fact table.
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ---

# %% [markdown]
# ### Step 3 : Data cleaning with DAX
# Sometimes you have to clean up existing columns before you can create new calculated columns.
#
# We want to add the retail price to our fact table for an item, but the retail price in the dimensional table is not formatted correctly. You will be cleaning up this column so we can add it afterwards.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Step 4: Connecting data from different tables
# You are asked to add the suggested retail price, the one you cleaned up in the previous exercise, to the main fact table. That way you can perform additional analysis in the future.
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
