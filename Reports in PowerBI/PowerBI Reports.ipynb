# %% [markdown]
# # Extend the Over Budget report
#
#
# We have big ideas for a report we want to make available to the public, and we need your expertise to get this done.
#
# The first page of this report should show **whether the county exceeded its budget, that is if the actual expenditures on a project or program exceeded what the county had been prepared to spend on it coming into the fiscal year.** We'd like to start by including the latest fiscal year of data, which is fiscal year (FY) 2019.
#
# ## Steps
# 1. ![[Pasted image 20251218213735.png]]
#
# 2.  ![[Pasted image 20251218214004.png]]
#
#
# 3. ![[Pasted image 20251218214025.png]]
#
# 4. ![[Pasted image 20251218214100.png]]
#
# 5. ![[Pasted image 20251218214113.png]]
#
# 6. ![[Pasted image 20251218214130.png]]

# %% [markdown]
# # Create drill-through pages
#
# We would like to be able to drill down to a page containing information for a given department. We want to make this as user-friendly as possible, making the experience more like navigating a webpage than switching to different pages and slicing in reports.
#
# In this exercise, you will **create a new department breakdown page that will link to the Over Budget page you created in the previous exercise**
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Visualizing over time
#
# The Department Breakdown page looks good, but we believe that visualizing changes over time would provide some interesting insights about the data. To that effect, we'd like to see, per cost center, a plot of the number of expenditures versus amount spent, broken down by month and year.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
