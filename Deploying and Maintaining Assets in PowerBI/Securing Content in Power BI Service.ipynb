# %% [markdown]
# # Securing Content in Power BI Service
#
#
# Learn how to protect your Power BI reports and datasets. Making content available to people is important; making content available only to the right people is critical.

# %% [markdown]
# # Sensitivity labels
#
# Which of the following is correct about sensitivity labels?
# ![Screenshot 2025-12-28 120428.png](<attachment:Screenshot 2025-12-28 120428.png>)

# %% [markdown]
# # Row-level security's benefit
#
# What is the primary benefit of using row-level security in Power BI?
#
# ![Screenshot 2025-12-28 120635.png](<attachment:Screenshot 2025-12-28 120635.png>)

# %% [markdown]
# # Matching permissions with activities
# Power BI offers four dataset permissions. Each permission confers certain rights. For each scenario, what is the minimum dataset permission required to satisfy the use case?
#
# ![image.png](attachment:image.png)
