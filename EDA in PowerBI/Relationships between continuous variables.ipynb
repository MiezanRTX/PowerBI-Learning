# %% [markdown]
# # Relationships between continuous variables
#
# ### Keypoints
#
# **Scatterplot**
#
# 1. What are scatterplots
#     - shows relationships between 2 conti var
#
# 2. Interpreting scatterplot
#     - Strong positive
#     - Storng negative
#     - Weak positive
#     - No relationship
#
# 3. Correlation Coefficient
#     - quanitify relationship
#     - Values = -1, 0 , 1
#
# 4. Adding context to a scatter plot
#
#     - additional visualizations to improve and unlock insights within scatter plots
#     - add colors, increase/decrease size, shapes, etc
#
# 5. Additional info
#     - Cluster that are very close together also shows stronger relatiohsips compared to dispersed.

# %% [markdown]
# ## Exploring AirBnB listings with Scatterplots
#
# ### Keypoints
#
# 1. How sqre foot affects listing price
#     - scatter plot
#     - adding city variable as legend
#
# 2. Adding stack bar chart
#     - as filter by city
#
# 3. Adding trend line
#
# 4. Corr of coeff
#     - use quick measure

# %% [markdown]
# ## Analyzing relationships with scatter plots
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Analyzing relationships with scatter plots
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Correlation of Coeeff
#
# ![image.png](attachment:image.png)
#
# Correlation of Coeff Calculation
#
# ![image-2.png](attachment:image-2.png)
