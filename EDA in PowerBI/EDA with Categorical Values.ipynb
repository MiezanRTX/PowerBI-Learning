# %% [markdown]
# # EDA with Categorical Values
#
# ## Notes
#
# 1. Visualization of categorical var
#
#     - Cat var and frequency -> **Histogram**
#     - Cat var and percentages -> **Pie chart**
#     - Proportion of multiple cat var -> **clustered column chart**
#     - Cat var with descriptive statistics -> **tables**
#     - Comparing distribution between multiple cat var -> **boxplots**
#
# 2. Creating new variables
#
#     - **Data mutation**: creating new variables to refine analysis or visualization.

# %% [markdown]
# ## Analyzing Categorical Data
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Propotions with Categorical Variables
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Analyzing Multiple Categorical Variables
#
# ![image.png](attachment:image.png)
