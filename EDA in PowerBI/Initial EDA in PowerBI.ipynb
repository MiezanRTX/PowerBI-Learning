# %% [markdown]
# # What is EDA ?
#
# - EDA is approach on Data Analysis that summarize the main characteristics of the data and its structure using statistics and data visualizations
#
# - There are **Six Steps in EDA**
#
# ## Six Steps of EDA
#
# 1. Understand the Data Structure
#
# 2. Identify missing Data
#
# 3. Desribing the Data
#
# 4. Identify Outliers
#
# 5. Explore relationships between variables
#
# 6. Forming Hypothesis
#
#
# ### 1. Understanding the Data Structure
#  - Data structure consists of rows and columns of the DS
#  - Datatype
#     - Continuous
#     - Categorical
#
#
# ### 2. Identifying Missing Data
#
#
# ### 3. Describing the Data

# %% [markdown]
# ## PowerBI Exercise
#
# ### Identifying Missing Data
#
# It's common to work with datasets which are missing information for one or more variables in one or more of the observations/records. Performing a quick analysis can help determine if the missing data is random or systematic (i.e. prominent within a specific group).
#
# #### Steps
# 1. Open the Power BI report named 1_1_identify.pbix from the Exercises folder
#
#     ![image.png](attachment:image.png)
#
#
# 2. Load the CSV file airbnb.csv from the Datasets folder.
#
#     ![image-2.png](attachment:image-2.png)
#
# 3. Create a new Card visualization showing the distinct count of listings and filter for listings without a price.
#
#     ![image-3.png](attachment:image-3.png)
#
# 4. Make a copy of this card and modify it to be a table named "Number of Listings with a Blank Price".
#
#     ![image-4.png](attachment:image-4.png)
#
# 5. Explore the counts of missing data in relation to review_scores_rating and city.
#
#     ![image-5.png](attachment:image-5.png)
#
# 6. It appears all listings without a price come from one city, what's the name of that city?
#     - ![image-6.png](attachment:image-6.png)
#
#         Sydney

# %% [markdown]
# ## Descriptive statistics for a variable
#
# An important part of the Exploratory Data Analysis (EDA) process is simply describing the data. A great place to start is to choose several variables of interest and use basic descriptive statistics - minimum, median, mean, maximum, standard deviation - to learn more about how those variables range in values (e.g. their distributions).\
#
# ### Steps
#
# 1. Create a new page named "describe"; rename the first page to "missing".
#
#     ![image.png](attachment:image.png)
#
# 2. Create a new Table visualization with the count of distinct listings.
#
# 3. Add a new column to the table showing the average price.
#
# 4. Add three more columns showing the minimum, median, and maximum for price.
#
#     ![image-2.png](attachment:image-2.png)
#
# 5. Repeat these steps to create a separate Table for host_acceptance_rate.
#
#     ![image-3.png](attachment:image-3.png)
#
# 6. Based on the values of the average and median, would you suspect the distribution for **price** to be...
#     - right-skewed

# %% [markdown]
# ## Imputation for missing data
#
# Missing data is a common occurrence when performing Exploratory Data Analysis on a new dataset. Rather than deleting missing records, sometimes it's more useful to use an imputation technique to fill in values with an estimate of what they would be. This is especially true when the number of missing values is small.
#
# ### Steps
#
# 1. Create a new page called "distribution". Change the data type of price to a decimal number.
#
#     ![image.png](attachment:image.png)
#
# 2. Create a new Table visualization. It should contain:
#     - listing_id as a distinct count,
#     - price as an average.
#     - price as a median.
#     Filter the page to show only listings from Sydney.
#
#     ![image-2.png](attachment:image-2.png)
#
#     ![image-3.png](attachment:image-3.png)
#
# 3. Create a new calculated column called updated_price which, if price is blank, sets the value to 110 (the median price for Sydney listings), otherwise uses the value of price.
#
#     you can create a logical statement if there are blank values in a column with the function ISBLANK().
#
#     ![image-4.png](attachment:image-4.png)
#
# 4. Add 2 more variables to the table:
#     - updated_price as a median.
#     - updated_price as an average.
#     - Change all values to currency data types with 2 decimals.
#
#     Note how this is a way to add 2 different metrics to a table: median and average.
#
#     ![image-5.png](attachment:image-5.png)
#
# 5. How did imputing the blank with the median affect the average listing price in Sydney?
#     - Decreased by $0.51
